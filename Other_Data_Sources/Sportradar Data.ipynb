# %% [markdown]
# # Sportradar Data
# The purpose of this notebook is to test out the Sportradar API data.

# %%
import http.client

# %%
conn = http.client.HTTPSConnection("api.sportradar.us")

# %%
conn.request("GET", "/mlb/trial/v7/en/games/a3308226-50a7-4059-9460-be41d1d03835/extended_summary.xml?api_key=ggvu9uy245fazrnxsb3wfd7c")

# %%
res = conn.getresponse()
data = res.read()

# %%
print(data.decode("utf-8"))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!-- Generation started @ 2021-03-04 01:40:22 UTC -->
# <game xmlns="http://feed.elasticstats.com/schema/baseball/v7/game.xsd" id="a3308226-50a7-4059-9460-be41d1d03835" status="closed" coverage="full" game_number="1" day_night="D" scheduled="2019-08-04T17:05:00+00:00" home_team="75729d34-bca7-4a0f-b3df-6f26c6ad3719" away_team="1d678440-b4b1-4954-9b39-70afb3ebbcfa" attendance="18837" duration="3:08" double_header="false" reference="564984">
#   <venue name="Oriole Park at Camden Yards" market="Baltimore" capacity="45971" surface="grass" address="333 West Camden Street" city="Baltimore" state="MD" zip="21201" country="USA" id="434aa63c-1049-4a54-a6bc-3790c7772ee1" field_orientation="NE" stadium_type="outdoor">
#     <location lat="39.2840361" lng="-76.619919"/>
#   </venue>
#   <broadcast network="MASN"/>
#   <weather>
# ...

# %%
type(data.decode("utf-8"))
# Out:
# str

# %% [markdown]
# Using [this article](https://medium.com/@robertopreste/from-xml-to-pandas-dataframes-9292980b1c1c) for help in converting to Pandas.

# %%
import xml.etree.ElementTree as et

# %%
xtree = et.parse(data.decode("utf-8"))
xroot = xtree.getroot()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-b102c8cd6df0> in <module>
# ----> 1 xtree = et.parse(data.decode("utf-8"))
#       2 xroot = xtree.getroot()
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/xml/etree/ElementTree.py in parse(source, parser)
#    1200     """
#    1201     tree = ElementTree()
# -> 1202     tree.parse(source, parser)
#    1203     return tree
#    1204
#
# ~/opt/anaconda3/envs/metis/lib/python3.8/xml/etree/ElementTree.py in parse(self, source, parser)
#     582         close_source = False
#     583         if not hasattr(source, "read"):
# --> 584             source = open(source, "rb")
#     585             close_source = True
#     586         try:
#
# ...
